# %%
import pandas as pd
import numpy as np
from utils import import_and_transform

# %%
user_data = import_and_transform("Data/train.parquet")
# Out:
# Only integers in userId - transformation successful

# %%
user_data
# Out:
#         userId  gender        registration  \
# 0      1000025       1 2018-07-10 09:30:08
# 1      1000035       0 2018-09-12 19:28:22
# 2      1000083       1 2018-09-07 18:01:49
# 3      1000103       0 2018-09-22 07:27:25
# 4      1000164       0 2018-08-12 09:32:01
# ...        ...     ...                 ...
# 19135  1999781       1 2018-08-31 02:26:28
# 19136  1999847       0 2018-09-26 04:22:19
# 19137  1999848       1 2018-08-31 07:58:01
# 19138  1999892       0 2018-08-20 15:55:52
# 19139  1999905       1 2018-07-24 01:52:55
#
#                                          location  level  num_sessions  \
# 0                           New Haven-Milford, CT      1            17
# 1                                    Columbia, SC      1            21
# 2                            Cincinnati, OH-KY-IN      1            11
# 3                            Cleveland-Elyria, OH      0             3
# 4                     Phoenix-Mesa-Scottsdale, AZ      1            15
# ...
